# %% [markdown]
# # Steiner Tree Problem in Unweighted Graphs

# %%
import random

import networkx as nx
from solver import Instance, SteinerTreeSolver

# %%
G = nx.connected_watts_strogatz_graph(20, 4, 0.2)
terminals = random.sample(list(G.nodes()), 5)

positions = nx.layout.kamada_kawai_layout(G)
nx.draw_networkx(
    G,
    pos=positions,
    node_color=["orange" if node in terminals else "grey" for node in G.nodes()],
)

# %%
solver = SteinerTreeSolver(Instance(G, terminals))
solution = solver.solve()
assert solution
# Out:
# Set parameter TimeLimit to value 900
# Set parameter NonConvex to value 0
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (linux64 - "Manjaro Linux")
#
# CPU model: AMD Ryzen 7 5700X 8-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 5 rows, 40 columns and 21 nonzeros
# Model fingerprint: 0x2f230608
# Variable types: 0 continuous, 40 integer (40 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.00s
# Presolved: 5 rows, 40 columns, 21 nonzeros
# Variable types: 0 continuous, 40 integer (40 binary)
#
# Root relaxation: objective 4.000000e+00, 8 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    4.00000    0    -          -    4.00000      -     -    0s
#      0     0    4.00000    0    4          -    4.00000      -     -    0s
#      0     0    4.50000    0    5          -    4.50000      -     -    0s
#      0     0    5.00000    0   14          -    5.00000      -     -    0s
#      0     0    5.00000    0    8          -    5.00000      -     -    0s
#      0     0    5.00000    0    6          -    5.00000      -     -    0s
# H    0     0                       6.0000000    5.00000  16.7%     -    0s
#      0     0    5.00000    0   14    6.00000    5.00000  16.7%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   MIR: 5
#   Lazy constraints: 30
#
# Explored 1 nodes (40 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 6
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.000000000000e+00, best bound 6.000000000000e+00, gap 0.0000%
#
# User-callback calls 147, time in user-callback 0.00 sec

# %%
# Draw the solution
nx.draw_networkx_nodes(G, pos=positions, node_color="lightgrey")
nx.draw_networkx_edges(G, pos=positions, style="dashed", edge_color="lightgrey")
nx.draw_networkx(
    solution,
    pos=positions,
    node_color=["orange" if node in terminals else "grey" for node in solution.nodes()],
)
